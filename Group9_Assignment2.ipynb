# %% [markdown]
# # Assignment 2: Machine Learning (Norwegian Airlines Stock Prediction)
#
# Group 9:
# - Henry Tran (s905398)
# - Markus Einan (s315297)
# - Benjamin Haug Weel (s331365)
# - Edvard Tollefsrud (s331390)

# %%
# Importing classes
import pandas as pd
import matplotlib
import numpy as np
from matplotlib import pyplot as plt

# Reading the NAS csv file to the dataset
df = pd.read_csv("NAS.csv")

# Visualisation of the dataset
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2003-12-18  19.482599  19.596901  19.025499  19.139799  19.139799
# 1     2003-12-19  19.368299  19.425501  18.282801  18.454201  18.454201
# 2     2003-12-22  18.739901  18.739901  17.997101  18.054300  18.054300
# 3     2003-12-23  17.997101  17.997101  17.368700  17.425800  17.425800
# 4     2003-12-24        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 4248  2020-10-12   0.709000   0.710000   0.650000   0.676800   0.676800
# 4249  2020-10-13   0.676800   0.676800   0.600000   0.600600   0.600600
# 4250  2020-10-14   0.601000   0.640000   0.596200   0.626000   0.626000
# 4251  2020-10-15   0.626000   0.626000   0.585000   0.605000   0.605000
# 4252  2020-10-16   0.605000   0.620000   0.601000   0.610600   0.610600
#
#           Volume
# 0      4978496.0
# 1      1410901.0
# 2       137047.0
# 3       229418.0
# 4            NaN
# ...          ...
# 4248  48320475.0
# 4249  47786200.0
# 4250  37534949.0
# 4251  26737615.0
# 4252  15754218.0
#
# [4253 rows x 7 columns]

# %% [markdown]
# # Data cleaning

# %%
# Finding null values in the dataset
df.isnull().sum()
# Out:
# Date          0
# Open         35
# High         35
# Low          35
# Close        35
# Adj Close    35
# Volume       35
# dtype: int64

# %%
# We see that there is 35 null values in the dataset and we remove them
df.dropna(inplace=True)

# Checking again for null values
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Looking again at the dataset and seeing that it is now only 4218 elements,
# which correlates with that we removed 35 from the starting 4253 elements
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2003-12-18  19.482599  19.596901  19.025499  19.139799  19.139799
# 1     2003-12-19  19.368299  19.425501  18.282801  18.454201  18.454201
# 2     2003-12-22  18.739901  18.739901  17.997101  18.054300  18.054300
# 3     2003-12-23  17.997101  17.997101  17.368700  17.425800  17.425800
# 7     2003-12-29  17.425800  17.425800  16.854500  17.254400  17.254400
# ...          ...        ...        ...        ...        ...        ...
# 4248  2020-10-12   0.709000   0.710000   0.650000   0.676800   0.676800
# 4249  2020-10-13   0.676800   0.676800   0.600000   0.600600   0.600600
# 4250  2020-10-14   0.601000   0.640000   0.596200   0.626000   0.626000
# 4251  2020-10-15   0.626000   0.626000   0.585000   0.605000   0.605000
# 4252  2020-10-16   0.605000   0.620000   0.601000   0.610600   0.610600
#
#           Volume
# 0      4978496.0
# 1      1410901.0
# 2       137047.0
# 3       229418.0
# 7       196206.0
# ...          ...
# 4248  48320475.0
# 4249  47786200.0
# 4250  37534949.0
# 4251  26737615.0
# 4252  15754218.0
#
# [4218 rows x 7 columns]

# %%
# Converting dataset['Date'] to date format
df.drop(['Open', 'High', 'Low', 'Adj Close', 'Volume'], axis=1, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Creating new data fields
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = month = df['Date'].dt.month
df['Day'] = day = df['Date'].dt.day
encodeDayName = pd.get_dummies(df['Date'].dt.day_name())
df = pd.concat([df, encodeDayName['Monday'], encodeDayName['Tuesday'], encodeDayName['Wednesday'], encodeDayName['Thursday'], encodeDayName['Friday']], axis=1)

# %%
# Looking at the new clean dataset
df
# Out:
#            Date      Close  Month  Day  Monday  Tuesday  Wednesday  Thursday  \
# 0    2003-12-18  19.139799     12   18       0        0          0         1
# 1    2003-12-19  18.454201     12   19       0        0          0         0
# 2    2003-12-22  18.054300     12   22       1        0          0         0
# 3    2003-12-23  17.425800     12   23       0        1          0         0
# 7    2003-12-29  17.254400     12   29       1        0          0         0
# ...         ...        ...    ...  ...     ...      ...        ...       ...
# 4248 2020-10-12   0.676800     10   12       1        0          0         0
# 4249 2020-10-13   0.600600     10   13       0        1          0         0
# 4250 2020-10-14   0.626000     10   14       0        0          1         0
# 4251 2020-10-15   0.605000     10   15       0        0          0         1
# 4252 2020-10-16   0.610600     10   16       0        0          0         0
#
#       Friday
# 0          0
# 1          1
# 2          0
# 3          0
# 7          0
# ...      ...
# 4248       0
# 4249       0
# 4250       0
# 4251       0
# 4252       1
#
# [4218 rows x 9 columns]

# %%
# Setting index as date
df['Date'] = pd.to_datetime(df.Date, format='%Y-%m-%d')
df.index = df['Date']

# Plotting the stock market history
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close price history')

# %% [markdown]
# # Linear regression

# %%
# Importing linear regression packages
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Training
x = df.drop('Close', axis='columns')
y = df['Close']

x_train, x_test, y_train , y_test = train_test_split(x, y, test_size=0.1)
x_train.shape, y_train.shape
x_test.shape, y_test.shape
# Out:
# ((422, 8), (422,))

# %%
# Creating linear regression object
regObj = LinearRegression(normalize=True)
regObj.fit(x_train, y_train) # Getting error on the fit method

regObj.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-29ba576aa092> in <module>
#       1 #Creating linear regression object
#       2 regObj = LinearRegression(normalize=True)
# ----> 3 regObj.fit(x_train, y_train) #Getting error on the fit method
#       4
#       5 regObj.predict()
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     532
#     533         if all(isinstance(dtype, np.dtype) for dtype in dtypes_orig):
# --> 534             dtype_orig = np.result_type(*dtypes_orig)
#     535
#     536     if dtype_numeric:
#
# <__array_function__ internals> in result_type(*args, **kwargs)
#
# TypeError: invalid type promotion
